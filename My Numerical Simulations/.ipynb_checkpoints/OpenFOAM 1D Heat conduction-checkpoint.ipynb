# %% [markdown]
# # OpenFOAM 1D Heat Conduction

# %%
import os, glob
import pandas as pd
import pysindy as ps
import matplotlib.pyplot as plt

import numpy as np
import sklearn as skl

from pydmd import DMD
from math import floor

from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D
from numpy import reshape

# %%
path = '/home/patrick/Documents/University/2021/MRN 412/Experimental data/1D OpenFOAM heat condution/Results1'
all_files = glob.glob(os.path.join(path, '1d_conduction_*.csv'))

df_from_each_file = (pd.read_csv(f, sep=',',  usecols=['Time','T']) for f in all_files)
df_merged = pd.concat(df_from_each_file)
data = df_merged.pivot(columns='Time', values='T')

# %%
data
# Out:
# Time  0.0     0.5     1.0     1.5     2.0     2.5     3.0     3.5     4.0     \
# 0      273.0  273.00  273.00  273.00  273.00  273.00  273.00  273.00  273.00
# 1      273.0  273.00  273.00  273.00  273.00  273.00  273.00  273.00  273.00
# 2      273.0  273.00  273.00  273.00  273.00  273.00  273.00  273.00  273.00
# 3      273.0  273.00  273.00  273.00  273.00  273.00  273.00  273.00  273.00
# 4      273.0  273.00  273.00  273.00  273.00  273.00  273.00  273.00  273.00
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 245    273.0  382.23  437.51  465.33  481.58  492.30  500.01  505.88  510.54
# 246    273.0  409.53  463.47  487.57  500.98  509.65  515.82  520.48  524.17
# 247    273.0  443.67  492.13  511.01  521.05  527.43  531.93  535.32  537.99
# 248    273.0  486.33  523.21  535.40  541.62  545.53  548.27  550.32  551.94
# 249    273.0  539.67  556.13  560.40  562.51  563.82  564.74  565.43  565.97
#
# Time  4.5     ...  1195.5  1196.0  1196.5  1197.0  1197.5  1198.0  1198.5  \
# 0     273.00  ...  273.60  273.60  273.60  273.60  273.60  273.60  273.60
# 1     273.00  ...  274.80  274.80  274.80  274.80  274.80  274.80  274.80
# 2     273.00  ...  276.00  276.00  276.00  276.00  276.00  276.00  276.00
# 3     273.00  ...  277.20  277.20  277.20  277.20  277.20  277.20  277.20
# 4     273.00  ...  278.39  278.39  278.39  278.39  278.39  278.39  278.39
# ..       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 245   514.35  ...  567.59  567.59  567.59  567.59  567.59  567.59  567.59
# 246   527.18  ...  568.79  568.79  568.79  568.79  568.79  568.79  568.79
# 247   540.16  ...  570.00  570.00  570.00  570.00  570.00  570.00  570.00
# 248   553.25  ...  571.20  571.20  571.20  571.20  571.20  571.20  571.20
# 249   566.41  ...  572.40  572.40  572.40  572.40  572.40  572.40  572.40
#
# Time  1199.0  1199.5  1200.0
# 0     273.60  273.60  273.60
# 1     274.80  274.80  274.80
# 2     276.00  276.00  276.00
# 3     277.20  277.20  277.20
# 4     278.39  278.39  278.39
# ..       ...     ...     ...
# 245   567.59  567.59  567.59
# 246   568.79  568.79  568.79
# 247   570.00  570.00  570.00
# 248   571.20  571.20  571.20
# 249   572.40  572.40  572.40
#
# [250 rows x 2401 columns]

# %%
xs, ts = np.meshgrid(data.axes[0], data.axes[1])
xs= xs.T
ts = ts.T

# %%
ts
# Out:
# array([[0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03],
#        [0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03],
#        [0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03],
#        ...,
#        [0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03],
#        [0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03],
#        [0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.1990e+03, 1.1995e+03,
#         1.2000e+03]])

# %%
split = 0.3 # Portion of training data

start_t= 2.5
train_t = 359.5
test_t = 600

dt_data = 0.5 # Spacing between readings

t_test = [10, 20, 30]

# %%
X_train = data.loc[:, start_t:train_t]

# %%
X_train_arr = X_train.to_numpy()
data_arr = data.to_numpy()

# %%
x = np.arange(0, data.shape[0], 1)
t = np.arange(0, data.shape[1]+0.1, dt_data)

xgrid, tgrid = np.meshgrid(x, t)

# %%
fig = plt.figure(figsize=(11,7))
plt.pcolor(data_arr)
plt.colorbar(label="Temperature [K]")
plt.title("Original data")
plt.xlabel("Snapshot num")
plt.ylabel("Position [mm]")
plt.show()

# %%
dmd = DMD(svd_rank=0, tlsq_rank=0, exact=False, opt=False, rescale_mode=None, forward_backward=False, sorted_eigs=False)
dmd.fit(X_train_arr)

'''
dmd.dmd_time['t0'] = start_t
dmd.dmd_time['tend'] = train_t 
dmd.dmd_time['dt'] *= dt
'''
# Out:
# /home/patrick/anaconda3/lib/python3.8/site-packages/pydmd/dmdbase.py:326: UserWarning: Input data matrix X has condition number 4983091.307398026. Consider preprocessing data, passing in augmented data matrix, or regularization methods.
#   warnings.warn(
# "\ndmd.dmd_time['t0'] = start_t\ndmd.dmd_time['tend'] = train_t \ndmd.dmd_time['dt'] *= dt\n"

# %%
for eig in dmd.eigs:
    print('Eigenvalue {}: distance from unit circle {}'.format(eig, np.abs(np.sqrt(eig.imag**2+eig.real**2) - 1)))
dmd.plot_eigs(show_unit_circle=True, show_axes=True)
# Out:
# Eigenvalue 0.44251201772787563: distance from unit circle 0.5574879822721244
# Eigenvalue 0.5836118712897387: distance from unit circle 0.4163881287102613
# Eigenvalue 0.7286761448834238: distance from unit circle 0.2713238551165762
# Eigenvalue 0.8166871141677944: distance from unit circle 0.18331288583220562
# Eigenvalue 0.8860237567126682: distance from unit circle 0.1139762432873318
# Eigenvalue 0.9226293046200372: distance from unit circle 0.07737069537996277
# Eigenvalue 0.9519650625420086: distance from unit circle 0.04803493745799137
# Eigenvalue 1.0000002586964503: distance from unit circle 2.5869645026155297e-07
# Eigenvalue 0.9968475331788588: distance from unit circle 0.003152466821141231
# Eigenvalue 0.987537581463358: distance from unit circle 0.012462418536641984
# Eigenvalue 0.972155768213709: distance from unit circle 0.02784423178629103

# %%
for mode in dmd.modes.T:
    plt.plot(range(data.shape[0]), mode.real)
    plt.title('Modes')
plt.show()

for dynamic in dmd.dynamics:
    plt.plot(dmd.dmd_timesteps, dynamic.real)
    plt.title('Dynamics')
plt.show()

# %%
fig = plt.figure(figsize=(11,7))
plt.pcolor(dmd.reconstructed_data.real)
plt.colorbar(label="Temperature [K]")
plt.title("Reconstructed data")
plt.xlabel("Snapshot num")
plt.ylabel("Position [mm]")
plt.show()

# %%
plt.plot((dmd.reconstructed_data.real[:, -1] - X_train_arr[:,-1]))

# %%
error = (dmd.reconstructed_data.real-dmd.snapshots)
print("The maximum temperature error is {} C".format(np.abs(error).max()))
fig = plt.figure(figsize=(11,7))
plt.pcolor(error)
plt.title("Error")
plt.colorbar(label="Temperature deviation[K]")
plt.xlabel("Snapshot num")
plt.ylabel("Position [mm]")
plt.show()
# Out:
# The maximum temperature error is 0.009339483448684405 C

# %%
i=0
for ts in t_test:
    plt.plot(dmd.snapshots[:, int(ts//dt_data)], label="{}".format(i))
    i+=1
    plt.plot(dmd.reconstructed_data[:, int(ts//dt_data)], label="{}".format(i))
    i+=1
    plt.legend()
plt.show()

# %% [raw]
# '''
# dmd.dmd_time['t0']
# tmd.dmdt_time['tend']
# dmd.dmd_time['dt'] *=
# '''

# %%
plt.plot(data.loc[:, 359.5])

# %%
print(f"Shape before manipulation: {dmd.reconstructed_data.shape}.")
print(f"Time data before manipulation: {dmd.dmd_time}.")
dmd.dmd_time['t0'] = start_t
dmd.dmd_time['dt'] = 0.5
dmd.dmd_time['tend'] = train_t/dt_data
print("Shape after manipulation: {}".format(dmd.reconstructed_data.shape))
print(f"Time data after manipulation: {dmd.dmd_time}.")
# Out:
# Shape before manipulation: (250, 715).
# Time data before manipulation: {'t0': 0, 'tend': 714, 'dt': 1}.
# Shape after manipulation: (250, 1434)
# Time data after manipulation: {'t0': 2.5, 'tend': 719.0, 'dt': 0.5}.

# %%
plt.plot(data.iloc[:,-1], 'r-', label='Original data, final T')
plt.plot(data.loc[:, train_t], 'k-', label='Original data at T')
plt.plot(dmd.reconstructed_data.real[:,-1], 'g-', label='Reconstructed data at tend')
plt.legend()

# %%
fig = plt.figure(figsize=(11,7))
plt.pcolor(dmd.reconstructed_data.real)
plt.colorbar()
plt.show()

# %%
dt = 0.25
for ts in t_test:
    plt.plot(dmd.reconstructed_data[:, int(ts//dt)])

# %%
model.print()
